# %%
import pandas as pd
import numpy as np

# %%
misclassified = pd.read_csv("val_misclassified_epoch5.csv")

# %%
misclassified.head()
# Out:
#                                                 text  label_id  true_label  \
# 0  This team are  scared of that lot, its disgust...        23          23
# 1                              * Song Credit: \n aka        21          21
# 2  “you already are” \ni love when blitz is a lit...        34          34
# 3  I see  and so many friends tonight  trying to ...        26          26
# 4  Thanks  for including our Super Savings Accoun...         1           1
#
#    pred_label   top3_labels
# 0          10    [10, 5, 9]
# 1          17  [17, 12, 38]
# 2           7   [7, 31, 30]
# 3           6   [6, 26, 22]
# 4          37   [37, 0, 39]
